# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# basic statistics

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
# a major thing I have found that 'EmployeeCount' and 'StandardHours' have no variance. so we can remove the attributes for prediction.

# %%
df.drop(['EmployeeCount','StandardHours'],axis=1,inplace=True)

# %%
df['Attrition_numeric']=df.Attrition.map({'Yes':1,'No':0})

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StockOptionLevel  \
# 0                        2  ...                        1                 0
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,fmt='0.2f')

# %%
# we have found some intutions from the heatmap
# there are some colinearities in the dataset like 'Joblevel' & 'Monthlyincome', 'Joblevel' & 'Totalworkingyears', 'Totalworkingyears' & 'Monthlyincome', 'Yearsincurrentrole' & 'Yearsatcompany', 'Yearswithcurrentmanager' & 'Yearsatcompany'

# %%
from scipy.stats import chi2_contingency

# %%
for i in cat_names:
    print(i)
    chi2,p,dof,ex=chi2_contingency(pd.crosstab(df.Attrition,df[i]))
    print(p)
# Out:
# BusinessTravel
# 5.608614476449931e-06
# Department
# 0.004525606574479633
# EducationField
# 0.006773980139025222
# Gender
# 0.29057244902890855
# JobRole
# 2.752481638050657e-15
# MaritalStatus
# 9.45551106034083e-11
# Over18
# 1.0
# OverTime
# 8.15842372153832e-21

# %%
# we found that the p value of 'Gender' attribute is greater than 0.05. so we can delete for modeling purpose.

# %%
# visualization

# %%
sns.countplot(df.Attrition)

# %%
# we found that approx 1/6 portion of total employee is suffering from attrition.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'Attrition_numeric'],
#       dtype='object')

# %%
df.hist(figsize=(15,15))
plt.show()

# %%
# this is the distribution of numric datasets. we find some important insights.
# employee age is normally distributed. most eployee's age is from 25 to 45.
# majority of the employess's home is within 10 km from office.
# majority of employees are satisfied with environment.
# majority of employees are in job level of 1 and 2.
# 50% of employees get salary within Rs. 10000
# majority of employees are in the company within 10 years.

# %%
bins=[18,30,40,50,60]
level=['young','elder','mid age','old']
df['age_status']=pd.cut(df['Age'],bins=bins,labels=level)

# %%
sns.countplot(df.age_status,hue=df.Attrition)

# %%
# we found that 'young' and 'elder' group of employees are suffering more from attritions. may be due to lack of patiences.

# %%
sns.countplot(df.MaritalStatus,hue=df.Attrition)

# %%
# 'single' status of employees are more attrition patient.

# %%
plt.figure(figsize=(8,6))
sns.countplot(df.Department,hue=df.Attrition)

# %%
# more employees work in R&D department and according to percentage, from 'sales' department, employees are more attrition patients.

# %%
plt.pie(df.groupby('Gender').size(),labels=['Female','Male'],explode=(0.05,0),radius=1,autopct='%0.2f%%',shadow=True)
plt.tight_layout()
plt.legend(loc='upper left')
plt.axis('equal')
plt.show()

# %%
# total there are 60% employees are male.

# %%
sns.countplot(df.Gender,hue=df.Attrition_numeric)

# %%
# male employees are more attrition patient.

# %%
plt.figure(figsize=(20,8))
sns.countplot(df.JobRole,)

# %%
# in the compnay 'sales executive','research scienist' and 'laboratory technician' are more.

# %%
sns.countplot(df.OverTime,hue=df.Attrition)

# %%
# we find that the employee who does overtime, are more attrition patient.

# %%
sns.countplot(df.JobLevel,hue=df.Attrition)

# %%
# more employees from junior level are suffers from attrition.

# %%
sns.countplot(df.age_status,hue=df.OverTime)

# %%
# all ege gruop of employees are facing attrition problem.

# %%
# building model

# %%
df.drop('Gender',axis=1,inplace=True)

# %%
x=df.drop(['Attrition_numeric','Attrition'],axis=1)
y=df['Attrition_numeric']

# %%
cat_col=[]
num_col=[]
for i in x.columns:
    if x[i].dtype== object:
        cat_col.append(i)
    else:
        num_col.append(i)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
cat_col
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %%
x.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
columntransformer=ColumnTransformer([('enocder',OneHotEncoder(),[1,3,6,12,14,18,19])],remainder='passthrough')
x=columntransformer.fit_transform(x)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
import numpy as np

# %%
x=sc.fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca=PCA()

# %%
principle_component=pca.fit_transform(x)

# %%
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.show()

# %%
# taking 35 principle component
pca=PCA(n_components=35)
new_data=pca.fit_transform(x)

# %%
pd.DataFrame(new_data)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.113905  2.212466 -0.978916 -0.320553  3.123347  0.698113 -0.172766
# 1     0.118449 -1.548307 -0.492684  0.893607 -1.192365 -2.444775  0.600761
# 2    -2.864759 -1.012159 -0.446935 -0.216700  2.981697  0.887081 -0.544748
# 3    -1.273026 -1.142314 -0.486529 -0.347892  1.753475 -2.562935  0.149427
# 4    -2.053379 -1.196833  0.263542 -0.570785 -0.978812  1.678559 -0.075049
# ...        ...       ...       ...       ...       ...       ...       ...
# 1465 -1.064436 -1.306103  0.140043 -0.207362 -1.363338 -0.831851  1.626481
# 1466  0.968072 -1.374686  0.089457 -0.405468 -1.327417  0.994968 -0.754505
# 1467 -1.033130 -1.192475  0.123802 -1.742859  0.824418 -1.000971 -1.472989
# 1468  1.230350  2.061409 -0.345036  0.507260 -0.897829 -0.954679  1.154877
# 1469 -1.429061 -1.036972  0.168869 -0.239635 -1.376233  1.513943 -0.850098
#
# ...

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
x_train,x_test,y_train,y_test=train_test_split(new_data,y,test_size=0.25)

# %%
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import RandomOverSampler
from imblearn.combine import SMOTETomek

# %%
os=SMOTETomek()
x_train_ns,y_train_ns=os.fit_sample(x_train,y_train)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest=RandomForestClassifier()
grid_param={
    'n_estimators':[80,100,120],
    'min_samples_leaf' : [1,2,3,4,5],
    'min_samples_split': [4,5,6]
}
grid_search=GridSearchCV(forest,param_grid=grid_param,cv=5)

# %%
grid_search.fit(x_train_ns,y_train_ns)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_samples_split': [4, 5, 6],
#                          'n_estimators': [80, 100, 120]})

# %%
grid_search.best_params_
# Out:
# {'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 120}

# %%
forest=RandomForestClassifier(n_estimators=120,min_samples_leaf=1,min_samples_split=4)
forest.fit(x_train_ns,y_train_ns)
# Out:
# RandomForestClassifier(min_samples_split=4, n_estimators=120)

# %%
pred=forest.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92       350
#            1       0.21      0.67      0.32        18
#
#     accuracy                           0.86       368
#    macro avg       0.60      0.77      0.62       368
# weighted avg       0.94      0.86      0.89       368

# %%
from xgboost import XGBRFClassifier

# %%
xgb=XGBRFClassifier()

# %%
xgb.fit(x_train_ns,y_train_ns)
# Out:
# XGBRFClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bytree=1, gamma=0, gpu_id=-1, importance_type='gain',
#                 interaction_constraints='', max_delta_step=0, max_depth=6,
#                 min_child_weight=1, missing=nan, monotone_constraints='()',
#                 n_estimators=100, n_jobs=0, num_parallel_tree=100,
#                 objective='binary:logistic', random_state=0, reg_alpha=0,
#                 scale_pos_weight=1, tree_method='exact', validate_parameters=1,
#                 verbosity=None)

# %%
pred=xgb.predict(x_test)

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       288
#            1       0.51      0.36      0.42        80
#
#     accuracy                           0.79       368
#    macro avg       0.67      0.63      0.65       368
# weighted avg       0.76      0.79      0.77       368

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()

# %%
gbc.fit(x_train_ns,y_train_ns)
# Out:
# GradientBoostingClassifier()

# %%
pred=gbc.predict(x_test)

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89       296
#            1       0.56      0.44      0.50        72
#
#     accuracy                           0.82       368
#    macro avg       0.72      0.68      0.69       368
# weighted avg       0.81      0.82      0.82       368

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
bagging=BaggingClassifier(base_estimator=KNeighborsClassifier(),n_estimators=20)

# %%
bagging.fit(x_train_ns,y_train_ns)
# Out:
# BaggingClassifier(base_estimator=KNeighborsClassifier(), n_estimators=20)

# %%
pred=bagging.predict(x_test)

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.92      0.79       235
#            1       0.68      0.29      0.41       133
#
#     accuracy                           0.70       368
#    macro avg       0.69      0.61      0.60       368
# weighted avg       0.69      0.70      0.66       368

# %%
bagging=BaggingClassifier(base_estimator=SVC(),n_estimators=20)
bagging.fit(x_train_ns,y_train_ns)
pred=bagging.predict(x_test)

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       311
#            1       0.51      0.51      0.51        57
#
#     accuracy                           0.85       368
#    macro avg       0.71      0.71      0.71       368
# weighted avg       0.85      0.85      0.85       368

# %%
bagging=BaggingClassifier(base_estimator=SVC(kernel='poly'),n_estimators=20)
bagging.fit(x_train_ns,y_train_ns)
pred=bagging.predict(x_test)

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       304
#            1       0.54      0.48      0.51        64
#
#     accuracy                           0.84       368
#    macro avg       0.72      0.70      0.71       368
# weighted avg       0.83      0.84      0.84       368

# %%
bagging=BaggingClassifier(base_estimator=RandomForestClassifier(),n_estimators=10)
bagging.fit(x_train_ns,y_train_ns)
pred=bagging.predict(x_test)

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91       316
#            1       0.47      0.52      0.50        52
#
#     accuracy                           0.85       368
#    macro avg       0.70      0.71      0.70       368
# weighted avg       0.86      0.85      0.85       368

# %%
from sklearn.tree import DecisionTreeClassifier
bagging=BaggingClassifier(base_estimator=DecisionTreeClassifier(),n_estimators=20)
bagging.fit(x_train_ns,y_train_ns)
pred=bagging.predict(x_test)

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90       315
#            1       0.42      0.45      0.44        53
#
#     accuracy                           0.83       368
#    macro avg       0.66      0.67      0.67       368
# weighted avg       0.84      0.83      0.83       368

# %%
from sklearn.naive_bayes import GaussianNB
bagging=BaggingClassifier(base_estimator=GaussianNB(),n_estimators=25)
bagging.fit(x_train_ns,y_train_ns)
pred=bagging.predict(x_test)

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.85       258
#            1       0.70      0.36      0.48       110
#
#     accuracy                           0.76       368
#    macro avg       0.74      0.65      0.66       368
# weighted avg       0.75      0.76      0.74       368

# %%
# I have tried multiple algorithms with different techniques. 
# The best fiiting and stable technique is bagging with base model svc with 'rbf' kernel.
